# %%
# Download stock data
tickers, (start_date, end_date) = config.get_tickers(), config.get_date_range()

print("Downloading stock price data...")
collector = StockDataCollector(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date
)

stock_data = collector.download(progress=False)
print(f"✓ Downloaded {len(collector)} stocks")

# Calculate features
collector.calculate_returns()
collector.calculate_volatility(window=21)
collector.handle_missing_data(method='forward_fill')

# Validate data
validation = collector.validate_data()
summary = collector.get_summary_statistics()

print("\n" + "="*70)
print("STOCK DATA SUMMARY")
print("="*70)
print(summary.to_string())
print()

# %%
# Load configuration
config = setup_config('../config/config.yaml')

print("="*70)
print("CONFIGURATION LOADED")
print("="*70)
print(f"Tickers: {config.get_tickers()}")
print(f"Date Range: {config.get_date_range()}")
print(f"Sentiment Model: {config.get_sentiment_model_type()}")
print(f"Risk-Free Rate: {config.get_risk_free_rate()}")
print()

# %% [markdown]
# ## Section 1: Data Loading & Preparation
#
# Load configuration and initialize data collectors for both stock prices and sentiment data.

# %%
import sys
sys.path.insert(0, '../')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Configure plotting
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 10

# Import our modules
from src.utils.config_loader import setup_config
from src.data_collection.stock_data import StockDataCollector
from src.data_collection.sentiment_data import SentimentDataPreparer

print("✓ Libraries imported successfully")
print(f"✓ Pandas version: {pd.__version__}")
print(f"✓ NumPy version: {np.__version__}")
print(f"✓ Matplotlib version: {plt.matplotlib.__version__}")

# %% [markdown]
# # Exploratory Data Analysis: Sentiment-Driven Portfolio Optimization
#
# **Objective**: Perform comprehensive exploratory analysis of stock price data and sentiment signals to understand patterns, correlations, and relationships for our portfolio optimization system.
#
# **Coverage**: 8 major stocks (AAPL, GOOGL, AMZN, MSFT, TSLA, META, NVDA, JPM) over 2019-2024
#
# **Sections**:
# 1. Data Loading & Preparation
# 2. Stock Price Analysis
# 3. Sentiment Data Analysis
# 4. Correlation & Relationship Analysis
# 5. Key Insights & Summary
#
# ---
